# %%
import pandas as pd

df = pd.read_csv('/Users/ale/Desktop/MySQL/Project-3/Economic Indicators And Inflation.csv')
df.head()
# Out:
#   Country   Year   GDP (in billion USD)   Inflation Rate (%)  \
# 0     USA   2010                15000.0                 1.64
# 1     USA   2011                15500.0                 3.16
# 2     USA   2012                16000.0                 2.07
# 3     USA   2013                16500.0                 1.50
# 4     USA   2014                17000.0                 1.62
#
#     Unemployment Rate (%)   Economic Growth (%)
# 0                    9.63                  2.55
# 1                    8.94                  1.53
# 2                    8.10                  2.28
# 3                    7.70                  1.84
# 4                    7.25                  2.53

# %%
df.shape
# Out:
# (304, 6)

# %%
df.columns
# Out:
# Index(['country', 'year', 'gdp_in_billion_usd', 'inflation_rate_percent',
#        'unemployment_rate_percent', 'economic_growth_percent'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('%', 'percent')
    .str.replace('(', '')
    .str.replace(')', '')
)

# %%
df['country'].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'India', 'UK', 'Canada',
#        'Russia', 'Australia', 'France', 'South Korea', 'Saudi Arabia',
#        'Brazil', 'Italy', 'Bangladesh', 'Indonesia', 'Turkey', 'Malaysia',
#        'Pakistan'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023, 2024, 2025])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                304 non-null    object
#  1   Year                   304 non-null    int64
#  2   GDP (in billion USD)   304 non-null    float64
#  3   Inflation Rate (%)     304 non-null    float64
#  4   Unemployment Rate (%)  304 non-null    float64
#  5   Economic Growth (%)    304 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 14.4+ KB

# %%
df.isnull().sum()
# Out:
# Country                  0
# Year                     0
# GDP (in billion USD)     0
# Inflation Rate (%)       0
# Unemployment Rate (%)    0
# Economic Growth (%)      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
